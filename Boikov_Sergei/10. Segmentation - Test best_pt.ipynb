# %%
import os
import shutil

root_path = '/content/'

# Переход в корневую директорию
os.chdir(root_path)

# @title Удаление всех папок и файлов в root_path
for file in os.listdir():
    file_path = os.path.join(root_path, file)
    try:
        if os.path.isfile(file_path) or os.path.islink(file_path):
            os.unlink(file_path)
        elif os.path.isdir(file_path):
            shutil.rmtree(file_path)
    except Exception as e:
        print(f"Failed to delete {file_path}. Reason: {e}")

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## **Установка YOLOv8**

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.196

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.0/78.2 GB disk)

# %%
from ultralytics import YOLO
import glob
from IPython.display import display, Image

# %% [markdown]
# ## **Тестирование лучшей модели, используя различные аргументы**

# %%
# Монтируем Google Диск
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# @title Сегментация объектов (segmentation), используя сохранённую лучшую модель best.pt

# Указываем путь, где находится файл для predict

base_path = '/content/drive/MyDrive/Intership_03/YOLOv8_trained/1Segmentation/'

last_best_path = f"{base_path}Last_Best/"
output_path = f"{base_path}"
#file_name = 'vid1_01m_19s_original.png'

#source_path = f'{output_path}Test_Predict/{file_name}'
source_path = f'{output_path}Test_Predict/'

print(f"last_best_path = {last_best_path}")
print(f"source_path = {source_path}")
# Out:
# last_best_path = /content/drive/MyDrive/Intership_03/YOLOv8_trained/1Segmentation/Last_Best/
# source_path = /content/drive/MyDrive/Intership_03/YOLOv8_trained/1Segmentation/Test_Predict/

# %%
# @title Параметры по умолчанию
# !yolo task=segment mode=predict model={last_best_path}best.pt source='{source_path}' conf=0.5 save=True

# Получение списка файлов и сортировка по имени
image_paths = sorted(glob.glob(f'{HOME}/runs/segment/predict/*.png'))

# Обработка файлов в порядке имён
for image_path in image_paths:
    display(Image(filename=image_path, width=1500))
    print("\n")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# @title Параметр boxes=False
# !yolo task=segment mode=predict model={last_best_path}best.pt source='{source_path}' conf=0.5 save=True boxes=False

# Получение списка файлов и сортировка по имени
image_paths = sorted(glob.glob(f'{HOME}/runs/segment/predict2/*.png'))

# Обработка файлов в порядке имён
for image_path in image_paths:
    display(Image(filename=image_path, width=1500))
    print("\n")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# @title Параметр show_labels=False
# !yolo task=segment mode=predict model={last_best_path}best.pt source='{source_path}' conf=0.5 save=True show_labels=False

# Получение списка файлов и сортировка по имени
image_paths = sorted(glob.glob(f'{HOME}/runs/segment/predict3/*.png'))

# Обработка файлов в порядке имён
for image_path in image_paths:
    display(Image(filename=image_path, width=1500))
    print("\n")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# @title Параметр show_conf=False
# !yolo task=segment mode=predict model={last_best_path}best.pt source='{source_path}' conf=0.5 save=True show_conf=False

# Получение списка файлов и сортировка по имени
image_paths = sorted(glob.glob(f'{HOME}/runs/segment/predict4/*.png'))

# Обработка файлов в порядке имён
for image_path in image_paths:
    display(Image(filename=image_path, width=1500))
    print("\n")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## **Вывод:**

# %% [markdown]
# **Классы городских объектов:**
#
#
#
# 1.   building-site (Строительная площадка)
# 2.   pits-with-water (Ямы с водой)
# 3.   buildings-residential (Жилые здания)
# 4.   buildings-children (Детские учреждения)
# 5.   grounds-play (Детские площадки)
# 6.   grounds-sports (Спортивные площадки)
# 7.   roads (Дороги)
# 8.   lawn (Газоны, лужайки)
